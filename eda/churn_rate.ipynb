# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.tools.plotting import scatter_matrix
from bokeh.charts import Bar, output_file, show
import datetime as dt
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support as pr
from sklearn.linear_model import LogisticRegression as LR
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.ensemble import GradientBoostingClassifier as GBC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
cols = [u'user_id', u'appopen', u'max_open/day',
       u'use_age', u'Churn', u'1d_open', u'2dacute', u'2d_crit',
       u'2d_bg_entry', u'min_bg_2d', u'max_bg_2d', u'1d_carbent', u'1d_wtent',
       u'1w_open', u'1w_crit', u'1wacute', u'1w_bg_entry', u'min_bg_1w',
       u'max_bg_1w', u'1w_carbent', u'1w_wtent', u'session_interval',
       u'1month/week_open', u'1m_crit', u'1macute', u'1m_bg_entry',
       u'min_bg_1m', u'max_bg_1m', u'1month_engagement', u'3month/week_open', u'3m_crit', u'3macute', u'3m_bg_entry', u'min_bg_3m',
       u'max_bg_3m', u'3month_engagement', u'tot_wt_ent',
       u'min_bg', u'max_bg', u'avg_bg', u'tot_critical', u'tot_acute',
       u'tot_bg_open', u'max_bg_open',
       u'diabetes.type_Gestational', u'diabetes.type_LADA',
       u'diabetes.type_Other', u'diabetes.type_Pre-diabetic',
       u'diabetes.type_Prediabetes', u'diabetes.type_Type I',
       u'diabetes.type_Type II', u'gender_Female', u'gender_Male', u'engagement', u'bg/appopen']

# %%
two_day_features = [u'user_id', u'max_open/day', u'1d_open', u'2dacute', u'2d_crit',
       u'2d_bg_entry', u'min_bg_2d', u'max_bg_2d', u'1d_carbent', u'1d_wtent']

# %%
first_week = [u'user_id', u'max_open/day', u'1d_open', u'2dacute', u'2d_crit', u'2d_bg_entry', u'min_bg_2d', u'max_bg_2d', u'1d_carbent', u'1d_wtent',
       u'1w_open', u'1w_crit', u'1wacute', u'1w_bg_entry', u'min_bg_1w',
       u'max_bg_1w', u'1w_carbent', u'1w_wtent']

# %%
first_month = [u'1month/week_open', u'1m_crit', u'1macute', u'1m_bg_entry',
       u'min_bg_1m', u'max_bg_1m', u'1month_engagement']

# %%
run eda_after1.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Salma/Project/eda/eda_after1.py in <module>()
#     158     df = fill_na_mean(df, mean_impute)
#     159     y_col = ['Churn']
# --> 160     df = convert_to_int(df, cols)
#     161     X = df[X_cols]
#     162     y= df[y_col]
#
# /Users/Salma/Project/eda/eda_after1.py in convert_to_int(df, columns)
#      68 def convert_to_int(df,columns):
#      69     for col in columns:
# ---> 70         df[col] = df[col].astype(int)
#      71     return df
#      72
#
# /Users/Salma/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2948
#    2949         mgr = self._data.astype(dtype=dtype, copy=copy,
# -> 2950                                 raise_on_error=raise_on_error, **kwargs)
#    2951         return self._constructor(mgr).__finalize__(self)
#    2952
#
# /Users/Salma/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, **kwargs)
#    2936
#    2937     def astype(self, dtype, **kwargs):
# -> 2938         return self.apply('astype', dtype=dtype, **kwargs)
#    2939
#    2940     def convert(self, **kwargs):
#
# /Users/Salma/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, raw, **kwargs)
#    2888
#    2889             kwargs['mgr'] = self
# -> 2890             applied = getattr(b, f)(**kwargs)
#    2891             result_blocks = _extend_blocks(applied, result_blocks)
#    2892
#
# /Users/Salma/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in astype(self, dtype, copy, raise_on_error, values, **kwargs)
#     432                **kwargs):
#     433         return self._astype(dtype, copy=copy, raise_on_error=raise_on_error,
# --> 434                             values=values, **kwargs)
#     435
#     436     def _astype(self, dtype, copy=False, raise_on_error=True, values=None,
#
# /Users/Salma/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in _astype(self, dtype, copy, raise_on_error, values, klass, mgr, **kwargs)
#     475
#     476                 # _astype_nansafe works fine with 1-d only
# --> 477                 values = com._astype_nansafe(values.ravel(), dtype, copy=True)
#     478                 values = values.reshape(self.shape)
#     479
#
# /Users/Salma/anaconda2/lib/python2.7/site-packages/pandas/core/common.pyc in _astype_nansafe(arr, dtype, copy)
#    1912
#    1913         if np.isnan(arr).any():
# -> 1914             raise ValueError('Cannot convert NA to integer')
#    1915     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#    1916         # work around NumPy brokenness, #1987
#
# ValueError: Cannot convert NA to integer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15826 entries, 0 to 15825
# Data columns (total 80 columns):
# Unnamed: 0                      15826 non-null int64
# Unnamed: 0.1                    15826 non-null int64
# level_0                         15826 non-null int64
# index                           15826 non-null float64
# user_id                         15826 non-null int64
# appopen                         15826 non-null int64
# max_open/day                    15826 non-null int64
# use_age                         15826 non-null int64
# Churn                           15826 non-null int64
# 1d_open                         15826 non-null int64
# 2dacute                         15826 non-null int64
# 2d_crit                         15826 non-null int64
# 2d_bg_entry                     15826 non-null int64
# min_bg_2d                       15826 non-null int64
# max_bg_2d                       15826 non-null int64
# 1d_carbent                      15826 non-null int64
# 1d_wtent                        15826 non-null int64
# 1w_open                         15826 non-null int64
# 1w_crit                         15826 non-null int64
# 1wacute                         15826 non-null int64
# 1w_bg_entry                     15826 non-null int64
# min_bg_1w                       15826 non-null int64
# max_bg_1w                       15826 non-null int64
# 1w_carbent                      15826 non-null int64
# 1w_wtent                        15826 non-null int64
# session_interval                15826 non-null int64
# 1month/week_open                5609 non-null float64
# count_x                         5609 non-null float64
# 1m_crit                         4491 non-null float64
# 1macute                         4491 non-null float64
# 1m_bg_entry                     4491 non-null float64
# min_bg_1m                       4491 non-null float64
# max_bg_1m                       4491 non-null float64
# 1month_engagement               5609 non-null float64
# 3month/week_open                2278 non-null float64
# count_y                         2278 non-null float64
# 3m_crit                         1805 non-null float64
# 3macute                         1805 non-null float64
# 3m_bg_entry                     1805 non-null float64
# min_bg_3m                       1805 non-null float64
# max_bg_3m                       1805 non-null float64
# 3month_engagement               2278 non-null float64
# tot_wt_ent                      4391 non-null float64
# max_wtent/day                   4391 non-null float64
# days_f0wt                       4391 non-null float64
# max_carbent/day                 2123 non-null float64
# days_f0crb                      2123 non-null float64
# tot_carbent                     2123 non-null float64
# min_bg                          15826 non-null float64
# max_bg                          15826 non-null float64
# avg_bg                          15826 non-null float64
# tot_critical                    15826 non-null float64
# tot_acute                       15826 non-null float64
# tot_bg_open                     5683 non-null float64
# >20_x                           4169 non-null float64
# <-20_x                          4169 non-null float64
# max_bg_open                     5683 non-null float64
# bg_user_age                     5683 non-null float64
# BG_Schedule                     3095 non-null object
# dateOfFirstLaunch               14093 non-null object
# Meal_Reminders_Set              1832 non-null object
# TrackingExerciseMinutes         8269 non-null object
# carbBudget                      10574 non-null float64
# diabetes.type_Gestational       15825 non-null float64
# diabetes.type_LADA              15825 non-null float64
# diabetes.type_Other             15825 non-null float64
# diabetes.type_Pre-diabetic      15825 non-null float64
# diabetes.type_Prediabetes       15825 non-null float64
# diabetes.type_Type I            15825 non-null float64
# diabetes.type_Type II           15825 non-null float64
# gender_Female                   15825 non-null float64
# gender_Male                     15825 non-null float64
# CarbEntryPreference_estimate    15825 non-null float64
# CarbEntryPreference_numeric     15825 non-null float64
# UserTreatmentType_Both          15825 non-null float64
# UserTreatmentType_Insulin       15825 non-null float64
# UserTreatmentType_Meds          15825 non-null float64
# engagement                      15826 non-null float64
# bg/appopen                      5683 non-null float64
# 1w_engagement                   15826 non-null float64
# dtypes: float64(51), int64(25), object(4)
# memory usage: 9.7+ MB

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'Unnamed: 0.1', u'level_0', u'index', u'user_id',
#        u'appopen', u'max_open/day', u'use_age', u'Churn', u'1d_open',
#        u'2dacute', u'2d_crit', u'2d_bg_entry', u'min_bg_2d', u'max_bg_2d',
#        u'1d_carbent', u'1d_wtent', u'1w_open', u'1w_crit', u'1wacute',
#        u'1w_bg_entry', u'min_bg_1w', u'max_bg_1w', u'1w_carbent', u'1w_wtent',
#        u'session_interval', u'1month/week_open', u'count_x', u'1m_crit',
#        u'1macute', u'1m_bg_entry', u'min_bg_1m', u'max_bg_1m',
#        u'1month_engagement', u'3month/week_open', u'count_y', u'3m_crit',
#        u'3macute', u'3m_bg_entry', u'min_bg_3m', u'max_bg_3m',
#        u'3month_engagement', u'tot_wt_ent', u'max_wtent/day', u'days_f0wt',
#        u'max_carbent/day', u'days_f0crb', u'tot_carbent', u'min_bg', u'max_bg',
#        u'avg_bg', u'tot_critical', u'tot_acute', u'tot_bg_open', u'>20_x',
#        u'<-20_x', u'max_bg_open', u'bg_user_age', u'BG_Schedule',
#        u'dateOfFirstLaunch', u'Meal_Reminders_Set', u'TrackingExerciseMinutes',
#        u'carbBudget', u'diabetes.type_Gestational', u'diabetes.type_LADA',
#        u'diabetes.type_Other', u'diabetes.type_Pre-diabetic',
#        u'diabetes.type_Prediabetes', u'diabetes.type_Type I',
#        u'diabetes.type_Type II', u'gender_Female', u'gender_Male',
#        u'CarbEntryPreference_estimate', u'CarbEntryPreference_numeric',
#        u'UserTreatmentType_Both', u'UserTreatmentType_Insulin',
#        u'UserTreatmentType_Meds', u'engagement', u'bg/appopen',
#        u'1w_engagement'],
#       dtype='object')

# %%
df[df['1month/week_open'].isnull()]
# Out:
#        Unnamed: 0  Unnamed: 0.1  level_0    index  user_id  appopen  \
# 3               3             5        5      5.0       10        7
# 4               4             8        8      8.0       13       10
# 5               5            11       11     11.0       18       22
# 6               6            12       12     12.0       20       10
# 7               7            14       14     14.0       26      125
# 9               9            17       17     17.0       29        5
# 10             10            18       18     18.0       31       19
# 11             11            19       19     19.0       32        6
# 12             12            20       20     20.0       34       25
# 13             13            21       21     21.0       35       12
# 14             14            22       22     22.0       37        8
# 15             16            25       25     25.0       41       16
# 17             18            29       29     29.0       49       18
# 18             19            30       30     30.0       50       63
# 19             20            33       33     33.0       63       49
# 20             21            34       34     34.0       67        7
# 22             24            45       45     45.0       86        6
# 23             25            46       46     46.0       87        8
# 25             27            49       49     49.0       90       14
# 26             28            50       50     50.0       91       15
# 27             29            51       51     51.0       94       14
# 30             32            57       57     57.0      102       46
# 31             33            58       58     58.0      103        6
# 32             34            62       62     62.0      112       24
# 35             37            66       66     66.0      124       13
# 36             38            67       67     67.0      125      175
# 27                        0.0    0.700000         NaN       0.714286
# 30                        0.0    0.484211         NaN       0.428571
# 31                        0.0    0.375000         NaN       0.571429
# 32                        0.0    3.000000         NaN       3.428571
# 35                        0.0    0.928571         NaN       1.285714
# 36                        0.0    1.535088         NaN       7.285714
# 37                        0.0    4.463855         NaN       5.857143
# 39                        0.0    6.000000         NaN       0.857143
# 40                        0.0    3.000000    0.166667       0.857143
# 43                        0.0    0.454545         NaN       0.571429
# ...                       ...         ...         ...            ...
# 15778                     1.0    0.227273    1.000000       0.571429
# 15779                     0.0    2.148148         NaN       4.571429
# 15780                     0.0    1.500000    5.500000       0.857143
# 15783                     0.0    3.500000         NaN       1.000000
# 15785                     0.0    7.000000         NaN       2.000000
# 15786                     0.0    3.500000         NaN       4.000000
# 15787                     0.0    0.434783         NaN       1.000000
# 15789                     0.0    0.425287    1.054054       0.428571
# 15790                     0.0    0.555556    0.100000       0.285714
# 15791                     0.0    2.857143         NaN       2.857143
# 15792                     1.0    3.571429    4.360000       3.571429
# 15793                     0.0    1.500000         NaN       1.714286
# 15794                     0.0    1.050000    0.428571       1.857143
# 15795                     0.0    1.250000    2.000000       0.714286
# 15802                     0.0    0.132353         NaN       0.857143
# 15803                     1.0    1.666667    1.600000       0.714286
# 15804                     0.0    2.333333    4.428571       1.000000
# 15806                     0.0    3.833333    0.021739       4.285714
# 15807                     0.0    0.842105         NaN       2.142857
# 15811                     0.0    0.523810         NaN       0.285714
# 15812                     0.0    7.000000         NaN       1.000000
# 15815                     0.0    2.900000         NaN       6.000000
# 15816                     0.0    0.451128         NaN       8.000000
# 15817                     0.0    5.333333    0.062500       2.285714
# 15818                     0.0    0.743590         NaN       3.000000
# 15820                     0.0    2.333333    2.714286       1.000000
# 15821                     0.0    0.230337         NaN       0.857143
# 15823                     0.0    3.000000         NaN       0.857143
# 15824                     0.0    2.000000         NaN       2.571429
# 15825                     0.0    0.666667    0.354167       6.714286
#
# [10217 rows x 80 columns]

# %%
zeros = []

# %%
zeros = ['1month/week_open' ,'1m_crit','1macute', '1m_bg_entry',                    
min_bg_1m                       4491 non-null float64
max_bg_1m                       4491 non-null float64
1month_engagement               5609 non-null float64
3month/week_open                2278 non-null float64
count_y                         2278 non-null float64
3m_crit                         1805 non-null float64
3macute                         1805 non-null float64
3m_bg_entry                     1805 non-null float64
min_bg_3m                       1805 non-null float64
max_bg_3m                       1805 non-null float64
3month_engagement               2278 non-null float64
tot_wt_ent                      4391 non-null float64
max_wtent/day                   4391 non-null float64
days_f0wt                       4391 non-null float64
max_carbent/day                 2123 non-null float64
days_f0crb                      2123 non-null float64
tot_carbent                     2123 non-null float64
tot_bg_open                     5683 non-null float64
>20_x                           4169 non-null float64
<-20_x                          4169 non-null float64
max_bg_open                     5683 non-null float64
bg_user_age                     5683 non-null float64
BG_Schedule                     3095 non-null object
dateOfFirstLaunch               14093 non-null object
Meal_Reminders_Set              1832 non-null object
TrackingExerciseMinutes         8269 non-null object
carbBudget                      10574 non-null float64
bg/appopen                      5683 non-null float64
